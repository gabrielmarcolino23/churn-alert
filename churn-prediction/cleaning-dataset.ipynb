# %% [markdown]
# ### Cleaning Dataset

# %%
# Importing the libraries
import pandas as pd

# %%
# Importing the dataset
df = pd.read_csv('C:/Users/Lenovo/Documents/zoppy/hackathon/churn-prediction/docs/dataset.csv')

# %%
# Target variable
target_variable = df['churn']

# Predictors Variables
predictors_variables = df.drop(['churn'], axis=1)

# %%
df.head()
# Out:
#                               companyId   createdAt   deletedAt      plan  \
# 0  61f4046e-641d-4fd5-a7b2-d0781810da35  13/09/2024         NaN  avançado
# 1  97029824-22cf-4697-9b48-cd5af0b0a9ae  15/07/2024  13/08/2024  avançado
# 2  94dd4e81-a391-49f8-9672-e9f8cab561c8  17/09/2024         NaN  avançado
# 3  6647f613-24c5-4c26-8619-e65872f12943  06/03/2024         NaN  avançado
# 4  0cff4d04-4cee-47c3-ad53-ed8861806e26  20/08/2024         NaN  avançado
#
#    numLogin  csm  numTickets  daysEmail  emailIntegration  daysEcommerce  ...  \
# 0       110    1           0        8.0                 1            0.0  ...
# 1        15    1           0        3.0                 1            2.0  ...
# 2        12    1          10        2.0                 1            1.0  ...
# 3        38    1           6      121.0                 1            2.0  ...
# 4        74    1           0        1.0                 1            1.0  ...
#
#    numCampains  receitaInflu  receitaTotal  receitaGiftback  receitacampanha  \
# 0           10       6616,71    1563709,28             0,00           179,69
# 1            9      15077,13     360196,97             0,00         15077,13
# 2            7      75121,56    2666049,13             0,00         73289,13
# 3            5       4467,00     450992,92             0,00          4467,00
# 4            1     239347,11    3621210,25         32928,24         71214,33
#
#    receitaPainelvendedor  receitaFluxo  ROI dataDif churn
# 0                   0,00       6437,02  0.0     NaN     0
# 1                   0,00          0,00  0.0    29.0     1
# 2                   0,00       1832,43  0.0     NaN     0
# 3                   0,00          0,00  0.0     NaN     0
# 4                   0,00          0,00  1.0     NaN     0
#
# [5 rows x 27 columns]

# %%
# Remove the columns that are not useful for the model
model_data = predictors_variables.drop(['companyId', 'createdAt','deletedAt', 'plan','dataDif'], axis=1)

# %%
# Subsisting the missing values 
model_data = model_data.fillna(-1)

# %%
# Replace , by . in the columns that are object
for column in model_data.columns:
    if model_data[column].dtype == 'object':
        model_data[column] = model_data[column].str.replace(',', '.').astype(float)

# %%
# Adding the target variable to the model_data
model_data['churn'] = target_variable

# %%
# # Exporting the data
model_data.to_csv('C:/Users/Lenovo/Documents/zoppy/hackathon/churn-prediction/docs/model_data.csv', index=False)
