# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Caminho absoluto para o arquivo Excel
df = pd.read_excel('C:/Users/Lenovo/Documents/zoppy/hackathon/reg-logistica/docs/basico.xlsx', sheet_name='Básico'.strip())

# %%
#Variavies Alvo CHURN
df_alvo = df['CHURN']

#Variaveis preditoras
df = df.drop(columns=['CHURN', 'id','CreatedAt','DeletedAt','DATADIF','nova planificação'])

# %%
df.head()
# Out:
#    login  gestor  Tickets  Email  Integração   API  Giftback  1 Campanha  \
# 0    150       1        0    3.0         3.0  14.0      19.0         3.0
# 1     27       0        0    7.0         8.0   7.0      13.0         9.0
# 2     27       0        0   81.0         0.0   2.0       3.0         4.0
# 3    100       1        0    0.0         0.0   8.0       NaN         2.0
# 4     38       0        0    0.0         0.0   9.0       0.0        12.0
#
#    # Campanhas            RI             RT  Giftback.1      Campanha  \
# 0           35  10083.559950  149406.590700    0.000000   8807.359970
# 1           29      0.000000    1300.279984    0.000000      0.000000
# 2           27   4531.300026   34877.190310  356.280006   3995.220016
# 3           26  12210.070050   57122.609980    0.000000  11258.170040
# 4           24  16400.290330  267911.200000    0.000000  16400.290330
#
#          Task        Fluxo       ROI
# 0    0.000000  1276.199982  0.285706
# 1    0.000000     0.000000       NaN
# 2    0.000000     0.000000  0.093929
# 3  951.900002     0.000000  0.348067
# 4    0.000000     0.000000  0.366153

# %%
df.describe()
# Out:
#             login      gestor     Tickets       Email  Integração         API  \
# count  556.000000  556.000000  556.000000  416.000000  473.000000  369.000000
# mean    37.037770    0.577338    1.780576   31.112981    5.386892   17.512195
# std     57.146346    0.494427    5.752748   37.840238   12.695939   23.698755
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      8.000000    0.000000    0.000000    3.000000    0.000000    5.000000
# 50%     23.000000    1.000000    0.000000   11.000000    2.000000    9.000000
# 75%     49.250000    1.000000    0.000000   52.000000    5.000000   19.000000
# max    958.000000    1.000000   30.000000  193.000000  151.000000  183.000000
#
#          Giftback  1 Campanha  # Campanhas             RI            RT  \
# count  401.000000  288.000000   556.000000     556.000000  5.560000e+02
# mean    20.798005   33.392361     1.440647    1884.898238  5.217518e+04
# std     23.546371   30.368392     3.913258    8022.445930  8.835194e+04
# min      0.000000    0.000000     0.000000       0.000000  0.000000e+00
# 25%      5.000000   12.000000     0.000000       0.000000  6.759140e+03
# 50%     13.000000   24.500000     0.000000       0.000000  2.485957e+04
# 75%     28.000000   43.000000     1.000000    1110.794987  5.961373e+04
# max    168.000000  156.000000    35.000000  100842.480000  1.046376e+06
#
#          Giftback.1      Campanha          Task         Fluxo         ROI
# count    556.000000    556.000000    556.000000    556.000000  261.000000
# mean     383.309676    757.433580    242.762518    222.511475    0.100737
# std     2070.759714   3443.453293   3830.535052   3688.962966    0.326143
# min        0.000000      0.000000      0.000000      0.000000   -0.010000
# 25%        0.000000      0.000000      0.000000      0.000000    0.000370
# 50%        0.000000      0.000000      0.000000      0.000000    0.027850
# 75%      143.982502      0.000000      0.000000      0.000000    0.087974
# max    34076.070050  51332.160160  89832.000000  86626.000000    2.947257

# %%
# Substiuindo valores nulos por -1
df.fillna(-1, inplace=True)

# %%
df.describe()
# Out:
#             login      gestor     Tickets       Email  Integração         API  \
# count  556.000000  556.000000  556.000000  556.000000  556.000000  556.000000
# mean    37.037770    0.577338    1.780576   23.026978    4.433453   11.285971
# std     57.146346    0.494427    5.752748   35.571337   11.927751   21.190323
# min      0.000000    0.000000    0.000000   -1.000000   -1.000000   -1.000000
# 25%      8.000000    0.000000    0.000000   -1.000000    0.000000   -1.000000
# 50%     23.000000    1.000000    0.000000    5.000000    1.000000    5.000000
# 75%     49.250000    1.000000    0.000000   30.250000    5.000000   14.000000
# max    958.000000    1.000000   30.000000  193.000000  151.000000  183.000000
#
#          Giftback  1 Campanha  # Campanhas             RI            RT  \
# count  556.000000  556.000000   556.000000     556.000000  5.560000e+02
# mean    14.721223   16.814748     1.440647    1884.898238  5.217518e+04
# std     22.255267   27.798630     3.913258    8022.445930  8.835194e+04
# min     -1.000000   -1.000000     0.000000       0.000000  0.000000e+00
# 25%     -1.000000   -1.000000     0.000000       0.000000  6.759140e+03
# 50%      7.000000    3.000000     0.000000       0.000000  2.485957e+04
# 75%     21.000000   26.000000     1.000000    1110.794987  5.961373e+04
# max    168.000000  156.000000    35.000000  100842.480000  1.046376e+06
#
#          Giftback.1      Campanha          Task         Fluxo         ROI
# count    556.000000    556.000000    556.000000    556.000000  556.000000
# mean     383.309676    757.433580    242.762518    222.511475   -0.483287
# std     2070.759714   3443.453293   3830.535052   3688.962966    0.593420
# min        0.000000      0.000000      0.000000      0.000000   -1.000000
# 25%        0.000000      0.000000      0.000000      0.000000   -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000   -1.000000
# 75%      143.982502      0.000000      0.000000      0.000000    0.020933
# max    34076.070050  51332.160160  89832.000000  86626.000000    2.947257

# %%
#Boxplot para cada variável numérica

for i in df.columns:
    if df[i].dtype == 'float64':
        df.boxplot(column=i)
        plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Função para remover outliers de forma iterativa usando o IQR
def remover_outliers_iterativo(df, coluna, multiplicador=1.5):
    df_sem_outliers = df.copy()  # Criar uma cópia do DataFrame original
    while True:
        # Cálculo do IQR (Interquartile Range)
        Q1 = df_sem_outliers[coluna].quantile(0.25)
        Q3 = df_sem_outliers[coluna].quantile(0.75)
        IQR = Q3 - Q1

        # Definir os limites de detecção de outliers
        limite_inferior = Q1 - multiplicador * IQR
        limite_superior = Q3 + multiplicador * IQR

        # Filtrar os dados sem outliers
        filtro = (df_sem_outliers[coluna] >= limite_inferior) & (df_sem_outliers[coluna] <= limite_superior)

        # Se todos os dados estiverem dentro dos limites, interromper o loop
        if filtro.all():
            break

        # Atualizar o DataFrame com os dados sem outliers
        df_sem_outliers = df_sem_outliers[filtro]
    
    return df_sem_outliers

# %%
# faca o codigo para fazer o boxplot de cada variavel numerica apos o tratamento de ouliers
for i in df.columns:
    if df[i].dtype == 'float64':
        df_sem_outliers = remover_outliers_iterativo(df, i)
        df_sem_outliers.boxplot(column=i)
        plt.show()

# %%
# FAça uma analise de quantos dados foram retirados pela analise de outliers comparando com a base inicial
print('Quantidade de dados na base original:', df.shape[0])
print('Quantidade de dados na base sem outliers:', df_sem_outliers.shape[0])
print('Quantidade de dados removidos:', df.shape[0] - df_sem_outliers.shape[0])
# Out:
# Quantidade de dados na base original: 556
# Quantidade de dados na base sem outliers: 553
# Quantidade de dados removidos: 3

# %%
import numpy as np

# %%
x = df_sem_outliers
y = df_alvo

# %%
churn_indices = y[y == 1].index
non_churn_indices = y[y == 0].index

# %%
non_churn_sample = np.random.choice(non_churn_indices, size=len(churn_indices), replace=False)
undersample_indices = np.concatenate([churn_indices, non_churn_sample])

# %%
# Definir as variáveis de recursos (X) e alvo (y)
X = df_sem_outliers  # df é o DataFrame com as variáveis preditoras
y = df_alvo  # churn é a variável alvo que você separou anteriormente

# Agora você pode usar os índices de subamostragem
X_bal = X.loc[undersample_indices]
y_bal = y.loc[undersample_indices]

# %%
#FAÇA a analise de correlação entre as variaveis preditoras e a variavel alvo
correlacao = df_sem_outliers.corrwith(df_alvo)
correlacao = correlacao.sort_values(ascending=False)
print(correlacao)

# Faça uma matriz de correlação
correlacao = df_sem_outliers.corr()
plt.matshow(correlacao)
plt.show()
# Out:
# Giftback.1    -0.042575
# Campanha      -0.046872
# Task          -0.051669
# Fluxo         -0.054128
# gestor        -0.060958
# RI            -0.077656
# # Campanhas   -0.077894
# Integração    -0.080937
# Tickets       -0.082336
# RT            -0.125847
# API           -0.151840
# login         -0.169673
# 1 Campanha    -0.179227
# ROI           -0.184152
# Email         -0.195816
# Giftback      -0.196015
# dtype: float64

# %%
#separar base de treino e teste
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_bal, y_bal, test_size=0.5, random_state=42)

#treinar um modelo de regressão logistica
from sklearn.linear_model import LogisticRegression

regressao_logistica = LogisticRegression()

regressao_logistica.fit(X_train, y_train)
# Out:
# c:\Users\Lenovo\Documents\zoppy\hackathon\venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#treinar com o modelo random forest
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier()

random_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#gradiente boosting
from sklearn.ensemble import GradientBoostingClassifier

gradiente_boosting = GradientBoostingClassifier()

gradiente_boosting.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
#avaliar o modelo

from sklearn.metrics import classification_report

y_pred = regressao_logistica.predict(X_test)
print(classification_report(y_test, y_pred))

y_pred = random_forest.predict(X_test)
print(classification_report(y_test, y_pred))

y_pred = gradiente_boosting.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      1.00      0.69        19
#            1       1.00      0.41      0.59        29
#
#     accuracy                           0.65        48
#    macro avg       0.76      0.71      0.64        48
# weighted avg       0.81      0.65      0.63        48
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.79      0.77        19
#            1       0.86      0.83      0.84        29
#
#     accuracy                           0.81        48
#    macro avg       0.80      0.81      0.81        48
# weighted avg       0.81      0.81      0.81        48
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82        19
#            1       0.89      0.86      0.88        29
#
#     accuracy                           0.85        48
#    macro avg       0.85      0.85      0.85        48
# weighted avg       0.86      0.85      0.85        48

# %%
#agora quero avaliar a importancia de cada variavel preditora
importancia = random_forest.feature_importances_
importancia = pd.Series(importancia, index=X.columns)
importancia = importancia.sort_values(ascending=False)
print(importancia)
# Out:
# login          0.201219
# Giftback       0.180168
# RT             0.129809
# Email          0.088852
# API            0.087561
# ROI            0.063920
# 1 Campanha     0.046220
# Integração     0.042495
# RI             0.040647
# gestor         0.033253
# Giftback.1     0.018812
# # Campanhas    0.017987
# Fluxo          0.013720
# Campanha       0.013362
# Task           0.012954
# Tickets        0.009022
# dtype: float64
